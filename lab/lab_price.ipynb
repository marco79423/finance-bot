# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext finance_bot.shell.extension

import numpy as np
import pandas as pd
pd.set_option("plotting.backend", "plotly")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The finance_bot.shell.extension extension is already loaded. To reload it, use:
#   %reload_ext finance_bot.shell.extension

# %%
# %autoreload 
from finance_bot.bot.tw_stock import TWStockBot

bot = TWStockBot()

bot.data['1101'].close
# Out:
# date
# 2004-02-11    19.30
# 2004-02-12    18.70
# 2004-02-13    20.00
# 2004-02-16    21.00
# 2004-02-17    21.00
#               ...
# 2023-07-27    37.35
# 2023-07-28    37.35
# 2023-07-31    37.30
# 2023-08-01    37.55
# 2023-08-02    37.20
# Name: close, Length: 4783, dtype: float64

# %%
bot.data['1101'].close.plot()
# Out:
# <div>                            <div id="3f8e9cf0-8ccf-4959-8877-14cfc946fac0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f8e9cf0-8ccf-4959-8877-14cfc946fac0")) {                    Plotly.newPlot(                        "3f8e9cf0-8ccf-4959-8877-14cfc946fac0",                        [{"hovertemplate":"variable=close\u003cbr\u003edate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"close","showlegend":true,"x":["2004-02-11T00:00:00","2004-02-12T00:00:00","2004-02-13T00:00:00","2004-02-16T00:00:00","2004-02-17T00:00:00","2004-02-18T00:00:00","2004-02-19T00:00:00","2004-02-20T00:00:00","2004-02-23T00:00:00","2
# ...

# %%
pd.DataFrame({
    'open': bot.data['1101'].open.loc['2020-01'],
    'close': bot.data['1101'].close.loc['2020-01'],
}, index=bot.data['1101'].close.loc['2020-01'].index).plot()
# Out:
# <div>                            <div id="f0c1944b-c4fa-4b9d-886f-d88d0a8af148" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0c1944b-c4fa-4b9d-886f-d88d0a8af148")) {                    Plotly.newPlot(                        "f0c1944b-c4fa-4b9d-886f-d88d0a8af148",                        [{"hovertemplate":"variable=open\u003cbr\u003edate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"open","orientation":"v","showlegend":true,"x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-
# ...
